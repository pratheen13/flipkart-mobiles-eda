# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mobiles=pd.read_csv('flip.csv')

# %%
mobiles.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5          11990
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5          11990
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3          13990
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3          13990
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5          11990
#
#    Original Price
# 0           15990
# 1           15990
# 2           17990
# 3           17990
# 4           15990

# %%
plt.figure(figsize=(50,10))
sns.countplot(x=mobiles.Brand)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=mobiles.Rating)
plt.show()

# %%
(mobiles['Selling Price'].value_counts().head(30)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
mobiles['Selling Price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mobiles[mobiles['Selling Price']<15000]['Selling Price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Selling Price'])
plt.show()

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Rating'])
plt.show()

# %%
plt.figure(figsize=(80,10))
sns.barplot(x=mobiles['Brand'],y=mobiles['Original Price'])
plt.show()

# %%
Price50 = mobiles.nlargest(50, "Selling Price")

# %%
Price50
# Out:
#         Brand               Model           Color Memory Storage  Rating  \
# 1233    Apple  iPhone 13 Pro Max      Sierra Blue   6 GB    1 TB     NaN
# 1255    Apple  iPhone 13 Pro Max             Gold   6 GB     NaN     NaN
# 1351    Apple  iPhone 13 Pro Max             Gold   6 GB    1 TB     NaN
# 1414    Apple  iPhone 13 Pro Max         Graphite   6 GB    1 TB     NaN
# 1459    Apple  iPhone 13 Pro Max           Silver   6 GB    1 TB     NaN
# 3044    Apple   iPhone 13 Pro Max          Silver    4GB    1 TB     4.7
# 3051    Apple   iPhone 13 Pro Max            Gold    4GB    1 TB     4.7
# 3057    Apple   iPhone 13 Pro Max        Graphite    4GB    1 TB     4.7
# 3058    Apple   iPhone 13 Pro Max     Sierra Blue    4GB    1 TB     4.7
# 2058  SAMSUNG          Fold 2 5G            Black  12 GB  256 GB     NaN
# 1393    Apple      iPhone 13 Pro         Graphite   6 GB    1 TB     NaN
# 1397    Apple      iPhone 13 Pro           Silver   6 GB    1 TB     NaN
# ...

# %%
Price50.replace(np.NaN,0)
# Out:
#         Brand               Model           Color Memory Storage  Rating  \
# 1233    Apple  iPhone 13 Pro Max      Sierra Blue   6 GB    1 TB     0.0
# 1255    Apple  iPhone 13 Pro Max             Gold   6 GB       0     0.0
# 1351    Apple  iPhone 13 Pro Max             Gold   6 GB    1 TB     0.0
# 1414    Apple  iPhone 13 Pro Max         Graphite   6 GB    1 TB     0.0
# 1459    Apple  iPhone 13 Pro Max           Silver   6 GB    1 TB     0.0
# 3044    Apple   iPhone 13 Pro Max          Silver    4GB    1 TB     4.7
# 3051    Apple   iPhone 13 Pro Max            Gold    4GB    1 TB     4.7
# 3057    Apple   iPhone 13 Pro Max        Graphite    4GB    1 TB     4.7
# 3058    Apple   iPhone 13 Pro Max     Sierra Blue    4GB    1 TB     4.7
# 2058  SAMSUNG          Fold 2 5G            Black  12 GB  256 GB     0.0
# 1393    Apple      iPhone 13 Pro         Graphite   6 GB    1 TB     0.0
# 1397    Apple      iPhone 13 Pro           Silver   6 GB    1 TB     0.0
# ...

# %%
Price50.isnull().sum()
# Out:
# Brand              0
# Model              0
# Color              0
# Memory             4
# Storage            1
# Rating            18
# Selling Price      0
# Original Price     0
# dtype: int64

# %%
Price50=Price50.dropna(how='any')

# %%
Price50.isnull().sum()
# Out:
# Brand             0
# Model             0
# Color             0
# Memory            0
# Storage           0
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64

# %%
Price50.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='Brand',y='Selling Price',data=Price50)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Original Price',y='Selling Price',data=mobiles)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x='Brand',y='Original Price' , data=mobiles.head(1000),hue='Selling Price')
plt.show()

# %%
sns.pairplot(Price50)
plt.show()

# %%
mobiles.sort_values(by="Selling Price",ascending=False)
# Out:
#         Brand               Model        Color Memory Storage  Rating  \
# 3051    Apple   iPhone 13 Pro Max         Gold    4GB    1 TB     4.7
# 1351    Apple  iPhone 13 Pro Max          Gold   6 GB    1 TB     NaN
# 1233    Apple  iPhone 13 Pro Max   Sierra Blue   6 GB    1 TB     NaN
# 1459    Apple  iPhone 13 Pro Max        Silver   6 GB    1 TB     NaN
# 3044    Apple   iPhone 13 Pro Max       Silver    4GB    1 TB     4.7
# ...       ...                 ...          ...    ...     ...     ...
# 811    GIONEE                L700        Black   8 MB   16 MB     3.9
# 814    GIONEE                 S96        Black   8 MB   16 MB     3.7
# 2011  SAMSUNG       GT 1200 R/I/M        Black    NaN    2 MB     4.1
# 987     Nokia        Ta -1010/105        Black   4 MB    4 MB     4.2
# 988     Nokia                 105        Black   4 MB    4 MB     4.3
#
#       Selling Price  Original Price
# 3051         179900          179900
# 1351         179900          179900
# ...

# %%
Mo=mobiles.replace(np.NaN,0)

# %%
Mo.sort_values(by="Selling Price",ascending=False)
# Out:
#         Brand               Model        Color Memory Storage  Rating  \
# 3051    Apple   iPhone 13 Pro Max         Gold    4GB    1 TB     4.7
# 1351    Apple  iPhone 13 Pro Max          Gold   6 GB    1 TB     0.0
# 1233    Apple  iPhone 13 Pro Max   Sierra Blue   6 GB    1 TB     0.0
# 1459    Apple  iPhone 13 Pro Max        Silver   6 GB    1 TB     0.0
# 3044    Apple   iPhone 13 Pro Max       Silver    4GB    1 TB     4.7
# ...       ...                 ...          ...    ...     ...     ...
# 811    GIONEE                L700        Black   8 MB   16 MB     3.9
# 814    GIONEE                 S96        Black   8 MB   16 MB     3.7
# 2011  SAMSUNG       GT 1200 R/I/M        Black      0    2 MB     4.1
# 987     Nokia        Ta -1010/105        Black   4 MB    4 MB     4.2
# 988     Nokia                 105        Black   4 MB    4 MB     4.3
#
#       Selling Price  Original Price
# 3051         179900          179900
# 1351         179900          179900
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(mobiles.corr(),annot=True)
plt.show()
